# %%
import pandas as pd
import numpy as np
df = pd.read_excel('orders_data.xlsx')
df.head(2)
# Out:
#               order_no                       order_date  buyer    ship_city  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST    Mr.  CHANDIGARH,
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST  Minam    PASIGHAT,
#
#           ship_state                 sku  \
# 0         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# 1  Women's Set of 5 Multicolor Pure Leather Singl...         1    ₹449.00
#
#   shipping_fee  cod        order_status
# 0          NaN  NaN  Delivered to buyer
# 1       ₹60.18  NaN  Delivered to buyer

# %%
df['buyer'][0]
# Out:
# 'Mr.'

# %%
df['buyer'][0]='Rajesh'
df['buyer'][0]
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_12868\1622410323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['buyer'][0]='Rajesh'
# 'Rajesh'

# %%
df['buyer']
# Out:
# 0          Rajesh
# 1           Minam
# 2      yatipertin
# 3           aciya
# 4         Susmita
#           ...
# 166        Shahin
# 167    Sharmistha
# 168      shashank
# 169        Jayeta
# 170         Varun
# Name: buyer, Length: 171, dtype: object

# %%
ser =pd.Series(np.random.rand(5))
df1 =pd.DataFrame(np.random.rand(5))
ser,df1
# Out:
# (0    0.232868
#  1    0.979955
#  2    0.817348
#  3    0.377150
#  4    0.457324
#  dtype: float64,
#            0
#  0  0.888933
#  1  0.294900
#  2  0.406936
#  3  0.638743
#  4  0.927143)

# %%
type(ser),type(df1)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df1[0][0]='hello'

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df1.to_numpy()
# Out:
# array([['hello'],
#        [0.2948999565779109],
#        [0.406936385662345],
#        [0.6387427094996211],
#        [0.927142839165922]], dtype=object)

# %%
df1[0][1]=1.2

# %%
df1
# Out:
#           0
# 0       1.2
# 1       1.2
# 2  0.406936
# 3  0.638743
# 4  0.927143

# %%
df1.sort_index(axis=1,ascending=False)
# Out:
#           0
# 0       1.2
# 1    0.2949
# 2  0.406936
# 3  0.638743
# 4  0.927143

# %%
df1
# Out:
#           0
# 0       1.2
# 1    0.2949
# 2  0.406936
# 3  0.638743
# 4  0.927143

# %%
newdf=df
copydf=df.copy()

# %%
copydf.loc['','buyer']='Buyer test'

# %%
copydf.loc[[1,2],:]
# Out:
#               order_no                       order_date       buyer  \
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
#
#    ship_city         ship_state                 sku  \
# 1  PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2  PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
#
#                                          description  quantity item_total  \
# 1  Women's Set of 5 Multicolor Pure Leather Singl...         1    ₹449.00
# 2  Women's Set of 5 Multicolor Pure Leather Singl...         1    ₹449.00
#
#   shipping_fee  cod        order_status    3
# 1       ₹60.18  NaN  Delivered to buyer  NaN
# 2       ₹60.18  NaN  Delivered to buyer  NaN

# %%
df
# Out:
#                 order_no                       order_date       buyer  \
# 0    405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST      Rajesh
# 1    404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4    402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
# ..                   ...                              ...         ...
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST      Shahin
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST  Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST    shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST      Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST       Varun
#
#         ship_city         ship_state                 sku  \
# 0     CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# ...

# %%
df.loc[(df['quantity']>2)]
# Out:
#                 order_no                       order_date    buyer  \
# 39   404-8031085-1381943   Fri, 26 Nov, 2021, 9:12 pm IST  Kangana
# 97   171-6267238-3345112   Thu, 18 Nov, 2021, 9:55 pm IST  Geetika
# 117  402-6563725-6606725   Tue, 21 Dec, 2021, 4:11 pm IST    Mitra
# 121  402-9977250-1302757   Tue, 21 Dec, 2021, 4:15 pm IST    Mitra
# 136  171-7361479-0297146  Fri, 10 Dec, 2021, 11:38 am IST     Amol
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST   Shahin
#
#       ship_city   ship_state                 sku  \
# 39   NEW DELHI,        DELHI  SKU:  54-D265-B74K
# 97    GURUGRAM,      HARYANA  SKU:  DN-0WDX-VYOT
# 117    Kolkata,  WEST BENGAL  SKU:  SB-WDQN-SDN9
# 121    CHENNAI,   TAMIL NADU  SKU:  SB-WDQN-SDN9
# 136       PUNE,  MAHARASHTRA  SKU:  DN-0WDX-VYOT
# 166     MUMBAI,  MAHARASHTRA  SKU:  DN-0WDX-VYOT
#
#                                            description  quantity item_total  \
# ...

# %%
copydf.drop([1],axis=0,inplace=True)
copydf
# Out:
#                 order_no                       order_date       buyer  \
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4    402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
# 5    406-9292208-6725123   Thu, 17 Jun, 2021, 9:12 pm IST    Subinita
# 6    404-5794317-7737924   Thu, 12 Aug, 2021, 8:03 pm IST  shailendra
# ..                   ...                              ...         ...
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST      Shahin
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST  Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST    shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST      Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST       Varun
#
#         ship_city         ship_state                 sku  \
# 2       PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# ...

# %%
copydf
# Out:
#                 order_no                       order_date       buyer  \
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4    402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
# 5    406-9292208-6725123   Thu, 17 Jun, 2021, 9:12 pm IST    Subinita
# 6    404-5794317-7737924   Thu, 12 Aug, 2021, 8:03 pm IST  shailendra
# ..                   ...                              ...         ...
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST      Shahin
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST  Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST    shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST      Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST       Varun
#
#         ship_city         ship_state                 sku  \
# 2       PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# ...

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf['cod'].isnull
# Out:
# <bound method Series.isnull of 0                   NaN
# 1                   NaN
# 2                   NaN
# 3      Cash On Delivery
# 4                   NaN
#              ...
# 166    Cash On Delivery
# 167                 NaN
# 168                 NaN
# 169    Cash On Delivery
# 170                 NaN
# Name: cod, Length: 171, dtype: object>

# %%
newdf.dropna()
# Out:
#                 order_no                       order_date            buyer  \
# 7    405-8702211-4054722  Wed, 29 Sept, 2021, 2:55 pm IST          Pratima
# 12   402-5321389-8685152  Sat, 16 Oct, 2021, 10:11 am IST          Blessan
# 16   405-6918787-5602743   Wed, 25 Aug, 2021, 7:48 am IST            Mosin
# 19   402-8678022-3083562   Fri, 1 Oct, 2021, 11:34 pm IST            Heena
# 25   402-2054361-4513137  Mon, 6 Sept, 2021, 12:46 pm IST           Ramesh
# 27   404-9680499-3084319   Fri, 29 Oct, 2021, 6:58 am IST          Manisha
# 28   406-3518585-4093925  Mon, 20 Sept, 2021, 6:41 pm IST                m
# 32   407-0864859-8033111   Fri, 29 Oct, 2021, 2:19 pm IST       Deepshikha
# 34   403-0713090-0169940   Thu, 28 Oct, 2021, 3:54 pm IST           sayani
# 38   407-0539421-4069143   Mon, 1 Nov, 2021, 11:33 am IST          Parmeet
# 45   404-6735919-2773947  Sun, 31 Oct, 2021, 11:28 pm IST  swagata13051978
# ...

# %%
newdf.drop_duplicates(subset='ship_city',keep='last')
# Out:
#                 order_no                       order_date        buyer  \
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST   yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST        aciya
# 5    406-9292208-6725123   Thu, 17 Jun, 2021, 9:12 pm IST     Subinita
# 6    404-5794317-7737924   Thu, 12 Aug, 2021, 8:03 pm IST   shailendra
# 9    171-7954707-4463549    Mon, 9 Aug, 2021, 4:47 pm IST  A.Jayaprada
# ..                   ...                              ...          ...
# 165  402-1808225-2809140   Sat, 25 Dec, 2021, 4:03 pm IST         User
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST   Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST     shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST       Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST        Varun
#
#         ship_city         ship_state                 sku  \
# ...

# %%
newdf.shape
# Out:
# (171, 12)

# %%
newdf['cod'].value_counts(dropna=True)
# Out:
# Cash On Delivery    47
# Name: cod, dtype: int64

# %%
newdf['order_no'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ...
